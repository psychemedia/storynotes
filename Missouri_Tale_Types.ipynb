# %% [markdown]
# # Tale Types Scraper
#
# The University of Missouri Libraries publish a useful look-up table of AT, ATU and Thompson Motif codes which might be handy to have in a simple database.
#
# The original pages can be found from this explanatory guide: https://libraryguides.missouri.edu/c.php?g=1039894&p=7541717

# %%
url = "https://libraryguides.missouri.edu/c.php?g=1039894&p=7609090"

# %%
import requests_cache
from datetime import timedelta

requests_cache.install_cache('web_cache', backend='sqlite', expire_after=timedelta(days=100))

from requests_html import HTMLSession
 
session = HTMLSession()
index_response = session.get(url)

# %% [markdown]
# The resource pages are linked from a menu bar. The links we want are all but the first and the last one:

# %%
link_elements = index_response.html.find('.nav-tabs')[0].find("li")[1:-1]
link_elements
# Out:
# [<Element 'li' class=('active',)>,
#  <Element 'li' class=()>,
#  <Element 'li' class=()>,
#  <Element 'li' class=()>,
#  <Element 'li' class=()>,
#  <Element 'li' class=()>,
#  <Element 'li' class=()>,
#  <Element 'li' class=()>]

# %%
index_links = [el.xpath("//a/@href")[0] for el in link_elements]
index_links
# Out:
# ['https://libraryguides.missouri.edu/c.php?g=1039894&p=7609090',
#  'https://libraryguides.missouri.edu/c.php?g=1039894&p=7610331',
#  'https://libraryguides.missouri.edu/c.php?g=1039894&p=7619154',
#  'https://libraryguides.missouri.edu/c.php?g=1039894&p=7620890',
#  'https://libraryguides.missouri.edu/c.php?g=1039894&p=7621605',
#  'https://libraryguides.missouri.edu/c.php?g=1039894&p=7624305',
#  'https://libraryguides.missouri.edu/c.php?g=1039894&p=7624836',
#  'https://libraryguides.missouri.edu/c.php?g=1039894&p=7635705']

# %% [markdown]
# The pages are split into separate tables which are embedded in particular block elements.

# %%
response = session.get(index_links[2])

# dot notation: . is class, # is id
#s-lib-box s-lib-box-std
boxes = response.html.find('.s-lib-box')
boxes
# Out:
# [<Element 'div' id='s-lg-box-24196290' class=('s-lib-box', 's-lib-box-std')>,
#  <Element 'div' id='s-lg-box-24196308' class=('s-lib-box', 's-lib-box-std')>,
#  <Element 'div' id='s-lg-box-24197326' class=('s-lib-box', 's-lib-box-std')>,
#  <Element 'div' id='s-lg-box-24197327' class=('s-lib-box', 's-lib-box-std')>,
#  <Element 'div' id='s-lg-box-24197417' class=('s-lib-box', 's-lib-box-std')>]

# %% [markdown]
# We can extract the box title as a category label:

# %%
category = boxes[0].find('h2')[0].text
category
# Out:
# 'Tales of Magic - Magic Object 560 - 571'

# %% [markdown]
# And we can grab the table within the box (I think there is just one table per box, so take the first, but we coul also go defensive on this to check for multiple tables...):

# %%
example_table = boxes[1].find('table')[0]
example_table
# Out:
# <Element 'table' class=('table', 'table-bordered') style='border: 0px solid rgb(180, 180, 180);'>

# %%
example_table.html
# Out:
# '<table class="table table-bordered" style="border: 0px solid rgb(180, 180, 180);">\n<tbody>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;571 \\&quot;All Stick Together\\&quot;&quot;}" height="21" style="height:21px;width:256px;">ATU Classification Type\xa0</td>\n<td style="width:276px;">\xa0AT Classification Type\xa0\xa0</td>\n<td style="width:631px;">Thompson Motif</td>\n</tr>\n<tr height="21">\n<td height="21" style="height:21px;">\xa0</td>\n<td>\xa0</td>\n<td style="width:631px;">\xa0</td>\n</tr>\n<tr height="21">\n<td height="21" style="height:21px;">ATU 571B Lover Exposed</td>\n<td>AT 571B Himphamp</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;H1010. &#x2020;H1010. Impossible tasks&quot;}" style="width:631px;">H1010. †H1010. Impossible tasks</td>\n</tr>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;571B Lover Exposed&quot;}" height="21" style="height:21px;">\xa0</td>\n<td>\xa0</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;D812.3. &#x2020;D812.3. Magic object received from devil.&quot;}">\n<div>\n<div>D812.3. †D812.3. Magic object received from devil.</div>\n</div>\n</td>\n</tr>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;571B Lover Exposed&quot;}" height="21" style="height:21px;">\xa0</td>\n<td>\xa0</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;D1413.8. &#x2020;D1413.8. Chamber-pot to which one sticks.&quot;}">\n<div>\n<div>D1413.8. †D1413.8. Chamber-pot to which one sticks.</div>\n</div>\n</td>\n</tr>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;571B Lover Exposed&quot;}" height="21" style="height:21px;">ATU 576 Magic Knife</td>\n<td>AT 576 Magic Knife</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;D838. &#x2020;D838. Magic object acquired by stealing&quot;}" style="width:631px;">D838. †D838. Magic object acquired by stealing</td>\n</tr>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;576 Magic Knife&quot;}" height="21" style="height:21px;">\xa0</td>\n<td>\xa0</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;D1083. &#x2020;D1083. Magic knife.&quot;}" style="width:631px;">D1083. †D1083. Magic knife.</td>\n</tr>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;576 Magic Knife&quot;}" height="21" style="height:21px;">\xa0</td>\n<td>\xa0</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;D1400.1.4.3. &#x2020;D1400.1.4.3. Magic knife conquers enemy.&quot;}">\n<div>\n<div>D1400.1.4.3. †D1400.1.4.3. Magic knife conquers enemy.</div>\n</div>\n</td>\n</tr>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;576 Magic Knife&quot;}" height="21" style="height:21px;">ATU 577 The King\'s Tasks</td>\n<td>AT 577 The King\'s Tasks</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;H335. &#x2020;H335. Tasks assigned suitors.&quot;}" style="width:631px;">H335. †H335. Tasks assigned suitors.</td>\n</tr>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;577 The King\'s Tasks&quot;}" height="21" style="height:21px;">\xa0</td>\n<td>\xa0</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;D1601.14. &#x2020;D1601.14. Self-chopping axe.&quot;}" style="width:631px;">D1601.14. †D1601.14. Self-chopping axe.</td>\n</tr>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;577 The King\'s Tasks&quot;}" height="21" style="height:21px;">\xa0</td>\n<td>\xa0</td>\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;D1601.15. &#x2020;D1601.15. Automatic shovel.&quot;}" style="width:631px;">D1601.15. †D1601.15. Automatic shovel.</td>\n</tr>\n<tr height="21">\n<td data-sheets-value="{&quot;1&quot;:2,&quot;2&quot;:&quot;577 The King\'s Tasks&quot;}" height="21" style="height:21px;">\xa0</td>\n<td>\xa0</td>\n<td data-sheets-value="{&quot;1& ...

# %% [markdown]
# We can parse that table into a pandas dataframe:

# %%
import pandas as pd

#Parse HTML table as dataframe
pd.read_html(example_table.html)[0]
# Out:
#                           0                                    1  \
# 0   ATU Classification Type               AT Classification Type
# 1                       NaN                                  NaN
# 2    ATU 571B Lover Exposed                     AT 571B Himphamp
# 3                       NaN                                  NaN
# 4                       NaN                                  NaN
# ..                      ...                                  ...
# 83       ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 84                      NaN                                  NaN
# 85                      NaN                                  NaN
# 86                      NaN                                  NaN
# 87                      NaN                                  NaN
#
#                                                     2
# 0                                      Thompson Motif
# 1                                                 NaN
# 2                     H1010. †H1010. Impossible tasks
# 3   D812.3. †D812.3. Magic object received from de...
# 4   D1413.8. †D1413.8. Chamber-pot to which one st...
# ..                                                ...
# 83                      B873.1. †B873.1. Giant louse.
# 84                   F983.2. †F983.2. Louse fattened.
# 85  H551. †H551. Princess offered to man who can o...
# 86  H522.1. †H522.1. Test: guessing origin of cert...
# 87  H573.3. †H573.3. Riddle solved by listening to...
#
# [88 rows x 3 columns]

# %% [markdown]
# The first table in the page has a structure distinct from all the rest. In particular, it includes some blank lines and the column headers.
#
# We could parse out the column headers, or we could set them explicitly. For conveniences, let's set them explicilty, then remove them if they appear in the table.
#
# For the first table in the page, we can then tidy up the dataframe by dropping at least the first three lines (the index count strats at 0), as well as dropping empty rows, resetting the index to account for that, and replacing null values with an empty string:

# %%
table_df = pd.read_html(example_table.html, skiprows=3)[0]
# Do some cleaning
table_df = table_df.dropna(axis=0, how='all').reset_index(drop=True).fillna('')

colnames = ["ATU Classification Type", "AT Classification Type", "Thompson Motif"]
#Explicitly set column names
table_df.columns = colnames

# Remove column names if they were in the table and reset the indeex
table_df = table_df[table_df["ATU Classification Type"]!="ATU Classification Type"].reset_index(drop=True)

table_df
# Out:
#    ATU Classification Type               AT Classification Type  \
# 0
# 1
# 2      ATU 576 Magic Knife                   AT 576 Magic Knife
# 3
# 4
# ..                     ...                                  ...
# 80      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 81
# 82
# 83
# 84
#
#                                        Thompson Motif
# 0   D812.3. †D812.3. Magic object received from de...
# 1   D1413.8. †D1413.8. Chamber-pot to which one st...
# 2      D838. †D838. Magic object acquired by stealing
# 3                         D1083. †D1083. Magic knife.
# 4   D1400.1.4.3. †D1400.1.4.3. Magic knife conquer...
# ..                                                ...
# 80                      B873.1. †B873.1. Giant louse.
# 81                   F983.2. †F983.2. Louse fattened.
# 82  H551. †H551. Princess offered to man who can o...
# 83  H522.1. †H522.1. Test: guessing origin of cert...
# 84  H573.3. †H573.3. Riddle solved by listening to...
#
# [85 rows x 3 columns]

# %% [markdown]
# We notice that sometimes there are blanks in the ATU and AT columns, the assumption being that the values are inherited from above. We can explicitly fill down these values:

# %%
table_df = table_df.replace("", None).fillna(method="ffill")
table_df
# Out:
#    ATU Classification Type               AT Classification Type  \
# 0
# 1
# 2      ATU 576 Magic Knife                   AT 576 Magic Knife
# 3      ATU 576 Magic Knife                   AT 576 Magic Knife
# 4      ATU 576 Magic Knife                   AT 576 Magic Knife
# ..                     ...                                  ...
# 80      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 81      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 82      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 83      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 84      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
#
#                                        Thompson Motif
# 0   D812.3. †D812.3. Magic object received from de...
# 1   D1413.8. †D1413.8. Chamber-pot to which one st...
# 2      D838. †D838. Magic object acquired by stealing
# 3                         D1083. †D1083. Magic knife.
# 4   D1400.1.4.3. †D1400.1.4.3. Magic knife conquer...
# ..                                                ...
# 80                      B873.1. †B873.1. Giant louse.
# 81                   F983.2. †F983.2. Louse fattened.
# 82  H551. †H551. Princess offered to man who can o...
# 83  H522.1. †H522.1. Test: guessing origin of cert...
# 84  H573.3. †H573.3. Riddle solved by listening to...
#
# [85 rows x 3 columns]

# %% [markdown]
# We can also add in the category:

# %%
table_df["category"] = category
table_df
# Out:
#    ATU Classification Type               AT Classification Type  \
# 0
# 1
# 2      ATU 576 Magic Knife                   AT 576 Magic Knife
# 3      ATU 576 Magic Knife                   AT 576 Magic Knife
# 4      ATU 576 Magic Knife                   AT 576 Magic Knife
# ..                     ...                                  ...
# 80      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 81      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 82      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 83      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 84      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
#
#                                        Thompson Motif  \
# 0   D812.3. †D812.3. Magic object received from de...
# 1   D1413.8. †D1413.8. Chamber-pot to which one st...
# 2      D838. †D838. Magic object acquired by stealing
# 3                         D1083. †D1083. Magic knife.
# 4   D1400.1.4.3. †D1400.1.4.3. Magic knife conquer...
# ..                                                ...
# 80                      B873.1. †B873.1. Giant louse.
# 81                   F983.2. †F983.2. Louse fattened.
# 82  H551. †H551. Princess offered to man who can o...
# 83  H522.1. †H522.1. Test: guessing origin of cert...
# 84  H573.3. †H573.3. Riddle solved by listening to...
#
#                                    category
# 0   Tales of Magic - Magic Object 560 - 571
# 1   Tales of Magic - Magic Object 560 - 571
# 2   Tales of Magic - Magic Object 560 - 571
# 3   Tales of Magic - Magic Object 560 - 571
# 4   Tales of Magic - Magic Object 560 - 571
# ..                                      ...
# 80  Tales of Magic - Magic Object 560 - 571
# 81  Tales of Magic - Magic Object 560 - 571
# 82  Tales of Magic - Magic Object 560 - 571
# 83  Tales of Magic - Magic Object 560 - 571
# 84  Tales of Magic - Magic Object 560 - 571
#
# [85 rows x 4 columns]

# %% [markdown]
# For the other tables, we don't need to drop any rows and we can recycle the column names, retaining the empty row dropper and null value cleaner just in case.
#
# Some of the other tables may have column names, others may not. So let's always add column names explicitly, then drop any row that appears to duplicate them:

# %%
# Work with the second table in a page... 
example_df2 = pd.read_html(boxes[1].find('table')[0].html)[0].dropna(axis=0, how='all').reset_index().fillna('')
example_df2.columns = table_df.columns
# Remove column names if they were in the table
example_df2 = example_df2[example_df2["ATU Classification Type"]!="ATU Classification Type"]

example_df2
# Out:
#     ATU Classification Type   AT Classification Type  \
# 0                         0  ATU Classification Type
# 1                         2   ATU 571B Lover Exposed
# 2                         3
# 3                         4
# 4                         5      ATU 576 Magic Knife
# ..                      ...                      ...
# 82                       83       ATU 857 Louse-Skin
# 83                       84
# 84                       85
# 85                       86
# 86                       87
#
#                          Thompson Motif  \
# 0                AT Classification Type
# 1                      AT 571B Himphamp
# 2
# 3
# 4                    AT 576 Magic Knife
# ..                                  ...
# 82  AT 621 The Louse-Skin (now ATU 857)
# 83
# 84
# 85
# 86
#
#                                              category
# 0                                      Thompson Motif
# 1                     H1010. †H1010. Impossible tasks
# 2   D812.3. †D812.3. Magic object received from de...
# 3   D1413.8. †D1413.8. Chamber-pot to which one st...
# 4      D838. †D838. Magic object acquired by stealing
# ..                                                ...
# 82                      B873.1. †B873.1. Giant louse.
# 83                   F983.2. †F983.2. Louse fattened.
# 84  H551. †H551. Princess offered to man who can o...
# 85  H522.1. †H522.1. Test: guessing origin of cert...
# 86  H573.3. †H573.3. Riddle solved by listening to...
#
# [87 rows x 4 columns]

# %% [markdown]
# Some of the tables include "metadata" rows rather than splitting things into separate pages.

# %%
response = session.get(index_links[5])

# dot notation: . is class, # is id
#s-lib-box s-lib-box-std
boxes = response.html.find('.s-lib-box')
borked_df = pd.read_html(boxes[0].find('table')[0].html, skiprows=3)[0]
borked_df = borked_df.dropna(axis=0, how='all').reset_index(drop=True).fillna('')
borked_df.columns = colnames
borked_df.iloc[10:25]
# Out:
#                        ATU Classification Type  \
# 10                  ATU 1008 Lighting the Road
# 11       ATU 1009 Guarding the Store-room Door
# 12                ATU 1010 Repairing the House
# 13  ATU 1011 Tearing up the Orchard (Vineyard)
# 14                 ATU 1012 Cleaning the Child
# 15      ATU 1013 Bathing (Warming) Grandmother
# 16    ATU 1029 The woman as Cuckoo in the Tree
# 17                               _____________
# 18                  ATU 1030 The Crop Division
# 19              ATU 1036 Hogs with Curly Tails
# 20          ATU 1045 Pulling the Lake Together
# 21                      ATU 1049 The heavy axe
# 22
# 23                      ATU 1050 Felling trees
# 24
#
#                                AT Classification Type  \
# 10  AT 1008 Lighting the Way by Setting the Barn o...
# 11      AT 1009 Guarding the Door by Carrying it Away
# 12                           AT 1010 Fixing Things Up
# 13                   AT 1011 Cutting Down the Orchard
# 14                AT 1012 Cleaning the Master's Child
# 15   AT 1013 Bathing the Grandmother in Boiling Water
# 16     AT 1029 The Bargain Ends When the Cuckoo Sings
# 17                                      _____________
# 18             AT 1030 Man and Ogre Share the Harvest
# 19                      AT 1036 Hogs with Curly Tails
# 20        AT 1045 Pulling Down the Forest with a Rope
# 21          AT 1049 The heavy Axe or the Giant Bucket
# 22
# 23                   AT 1050 Contest in Felling Trees
# 24
#
#                                        Thompson Motif
# 10  K1412. Lighting the road (or painting the hous...
# 11                          K1413. Guarding the door.
# 12                         K1415. Repairing the house
# 13          K1416. Tearing up the orchard (vineyard).
# 14                       K1461.1. Cleaning the child.
# 15  K1462. Washing the grandmother -- in boiling w...
# 16  K1691. The woman as cuckoo on the tree shot down.
# 17       Partnership between Man and Ogre 1030 - 1059
# 18  K171.1. Deceptive crop division: above the gro...
# 19  K171.4. Deceptive division of pigs: curly and ...
# 20  K1744. Hero threatens to pull the lake togethe...
# 21                 K1741.1. Felling the whole forest.
# 22                  K1741.3. Bringing the whole well.
# 23                K44. Deceptive contest in chopping.
# 24         K178. Deceptive bargain: felling the tree.

# %% [markdown]
# We can split the table on these "headers" and use the new heading as the category:

# %%
# Find index of split rows
borked_df[borked_df["ATU Classification Type"].str.startswith("__")]
# Out:
#    ATU Classification Type AT Classification Type  \
# 17           _____________          _____________
# 29           _____________          _____________
# 53           _____________          _____________
# 72           _____________          _____________
# 80           _____________          _____________
# 92           _____________          _____________
#
#                                   Thompson Motif
# 17  Partnership between Man and Ogre 1030 - 1059
# 29      Contest between Man and Ogre 1060 - 1114
# 53          Man Kills (Injures) Ogre 1115 - 1144
# 72            Ogre Frightened by Man 1145 - 1154
# 80             Man Outwits the Devil 1155 - 1169
# 92        Souls Saved from the Devil 1170 - 1199

# %% [markdown]
# If we get the index values of these we can iteratively split the dataframe:

# %%
split_indexes = borked_df[borked_df["ATU Classification Type"].str.startswith("__")].index.to_list()
split_indexes

split_dfs = []

prev_ix = 0
for ix in split_indexes:
    tmp_df = borked_df.iloc[prev_ix:ix, :].reset_index(drop=True)
    split_dfs.append(tmp_df)
    prev_ix = ix

# Remaining part:
tmp_df = borked_df.iloc[prev_ix:, :].reset_index(drop=True)
split_dfs.append(tmp_df)

# %% [markdown]
# The first row of each of the split dataframes contains the new category:

# %%
split_dfs[2].iloc[0]
# Out:
# ATU Classification Type                               _____________
# AT Classification Type                                _____________
# Thompson Motif             Contest between Man and Ogre 1060 - 1114
# Name: 0, dtype: object

# %% [markdown]
# We can process the dataframes by extracting the category, updating the dataframe with it, and dropping the metadata row:

# %%
for split_df in split_dfs[1:]:
    category = split_df.iloc[0, 2]
    split_df["category"] = category
    # Because we are modifying the dataframes as referenced objects, we change them inplace
    split_df.drop(0, inplace=True)
    split_df.reset_index(drop=True, inplace=True)
    
split_dfs[1].head()
# Out:
#               ATU Classification Type  \
# 0          ATU 1030 The Crop Division
# 1      ATU 1036 Hogs with Curly Tails
# 2  ATU 1045 Pulling the Lake Together
# 3              ATU 1049 The heavy axe
# 4
#
#                         AT Classification Type  \
# 0       AT 1030 Man and Ogre Share the Harvest
# 1                AT 1036 Hogs with Curly Tails
# 2  AT 1045 Pulling Down the Forest with a Rope
# 3    AT 1049 The heavy Axe or the Giant Bucket
# 4
#
#                                       Thompson Motif  \
# 0  K171.1. Deceptive crop division: above the gro...
# 1  K171.4. Deceptive division of pigs: curly and ...
# 2  K1744. Hero threatens to pull the lake togethe...
# 3                 K1741.1. Felling the whole forest.
# 4                  K1741.3. Bringing the whole well.
#
#                                        category
# 0  Partnership between Man and Ogre 1030 - 1059
# 1  Partnership between Man and Ogre 1030 - 1059
# 2  Partnership between Man and Ogre 1030 - 1059
# 3  Partnership between Man and Ogre 1030 - 1059
# 4  Partnership between Man and Ogre 1030 - 1059

# %% [markdown]
# We can split out each row into more detail:

# %%
def ATU_splitter(cell):
    """Split out ATU Classification type elements."""
    if cell:
        parts = cell.split()
        return pd.Series({#"ATU_code":" ".join(parts[:2]),
                          "ATU_code": parts[1],
                          "ATU_label": " ".join(parts[2:])})
    return pd.Series({"ATU_code":'', "ATU_label":''})

table_df[["ATU_code","ATU_label"]]= table_df["ATU Classification Type"].apply(ATU_splitter)
table_df
# Out:
#    ATU Classification Type               AT Classification Type  \
# 0
# 1
# 2      ATU 576 Magic Knife                   AT 576 Magic Knife
# 3      ATU 576 Magic Knife                   AT 576 Magic Knife
# 4      ATU 576 Magic Knife                   AT 576 Magic Knife
# ..                     ...                                  ...
# 80      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 81      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 82      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 83      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 84      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
#
#                                        Thompson Motif  \
# 0   D812.3. †D812.3. Magic object received from de...
# 1   D1413.8. †D1413.8. Chamber-pot to which one st...
# 2      D838. †D838. Magic object acquired by stealing
# 3                         D1083. †D1083. Magic knife.
# 4   D1400.1.4.3. †D1400.1.4.3. Magic knife conquer...
# ..                                                ...
# 80                      B873.1. †B873.1. Giant louse.
# 81                   F983.2. †F983.2. Louse fattened.
# 82  H551. †H551. Princess offered to man who can o...
# 83  H522.1. †H522.1. Test: guessing origin of cert...
# 84  H573.3. †H573.3. Riddle solved by listening to...
#
#                                    category ATU_code    ATU_label
# 0   Tales of Magic - Magic Object 560 - 571
# 1   Tales of Magic - Magic Object 560 - 571
# 2   Tales of Magic - Magic Object 560 - 571      576  Magic Knife
# 3   Tales of Magic - Magic Object 560 - 571      576  Magic Knife
# 4   Tales of Magic - Magic Object 560 - 571      576  Magic Knife
# ..                                      ...      ...          ...
# 80  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin
# 81  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin
# 82  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin
# 83  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin
# 84  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin
#
# [85 rows x 6 columns]

# %%
def AT_splitter(cell):
    """Split out AT Classification type elements."""
    if cell:
        parts = cell.split()
        return pd.Series({#"AT_code":" ".join(parts[:2]),
                          "AT_code": parts[1],
                          "AT_label": " ".join(parts[2:])})
    return pd.Series({"AT_code":'', "AT_label":''})

table_df[["AT_code","AT_label"]]= table_df["AT Classification Type"].apply(AT_splitter)
table_df
# Out:
#    ATU Classification Type               AT Classification Type  \
# 0
# 1
# 2      ATU 576 Magic Knife                   AT 576 Magic Knife
# 3      ATU 576 Magic Knife                   AT 576 Magic Knife
# 4      ATU 576 Magic Knife                   AT 576 Magic Knife
# ..                     ...                                  ...
# 80      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 81      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 82      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 83      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 84      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
#
#                                        Thompson Motif  \
# 0   D812.3. †D812.3. Magic object received from de...
# 1   D1413.8. †D1413.8. Chamber-pot to which one st...
# 2      D838. †D838. Magic object acquired by stealing
# 3                         D1083. †D1083. Magic knife.
# 4   D1400.1.4.3. †D1400.1.4.3. Magic knife conquer...
# ..                                                ...
# 80                      B873.1. †B873.1. Giant louse.
# 81                   F983.2. †F983.2. Louse fattened.
# 82  H551. †H551. Princess offered to man who can o...
# 83  H522.1. †H522.1. Test: guessing origin of cert...
# 84  H573.3. †H573.3. Riddle solved by listening to...
#
#                                    category ATU_code    ATU_label AT_code  \
# 0   Tales of Magic - Magic Object 560 - 571
# 1   Tales of Magic - Magic Object 560 - 571
# 2   Tales of Magic - Magic Object 560 - 571      576  Magic Knife     576
# 3   Tales of Magic - Magic Object 560 - 571      576  Magic Knife     576
# 4   Tales of Magic - Magic Object 560 - 571      576  Magic Knife     576
# ..                                      ...      ...          ...     ...
# 80  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
# 81  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
# 82  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
# 83  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
# 84  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
#
#                         AT_label
# 0
# 1
# 2                    Magic Knife
# 3                    Magic Knife
# 4                    Magic Knife
# ..                           ...
# 80  The Louse-Skin (now ATU 857)
# 81  The Louse-Skin (now ATU 857)
# 82  The Louse-Skin (now ATU 857)
# 83  The Louse-Skin (now ATU 857)
# 84  The Louse-Skin (now ATU 857)
#
# [85 rows x 8 columns]

# %%
def Thompson_Motif_splitter(cell):
    """Split out Thompson Motif elements."""
    if cell:
        parts = cell.split()
        return pd.Series({"Motif_code":" ".join(parts[:1]).strip("."), "Motif_label": " ".join(parts[1:])})
    return pd.Series({"Motif_code":'', "Motif_label":''})

table_df[["Motif_code","Motif_label"]]= table_df["Thompson Motif"].apply(Thompson_Motif_splitter)
table_df
# Out:
#    ATU Classification Type               AT Classification Type  \
# 0
# 1
# 2      ATU 576 Magic Knife                   AT 576 Magic Knife
# 3      ATU 576 Magic Knife                   AT 576 Magic Knife
# 4      ATU 576 Magic Knife                   AT 576 Magic Knife
# ..                     ...                                  ...
# 80      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 81      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 82      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 83      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
# 84      ATU 857 Louse-Skin  AT 621 The Louse-Skin (now ATU 857)
#
#                                        Thompson Motif  \
# 0   D812.3. †D812.3. Magic object received from de...
# 1   D1413.8. †D1413.8. Chamber-pot to which one st...
# 2      D838. †D838. Magic object acquired by stealing
# 3                         D1083. †D1083. Magic knife.
# 4   D1400.1.4.3. †D1400.1.4.3. Magic knife conquer...
# ..                                                ...
# 80                      B873.1. †B873.1. Giant louse.
# 81                   F983.2. †F983.2. Louse fattened.
# 82  H551. †H551. Princess offered to man who can o...
# 83  H522.1. †H522.1. Test: guessing origin of cert...
# 84  H573.3. †H573.3. Riddle solved by listening to...
#
#                                    category ATU_code    ATU_label AT_code  \
# 0   Tales of Magic - Magic Object 560 - 571
# 1   Tales of Magic - Magic Object 560 - 571
# 2   Tales of Magic - Magic Object 560 - 571      576  Magic Knife     576
# 3   Tales of Magic - Magic Object 560 - 571      576  Magic Knife     576
# 4   Tales of Magic - Magic Object 560 - 571      576  Magic Knife     576
# ..                                      ...      ...          ...     ...
# 80  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
# 81  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
# 82  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
# 83  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
# 84  Tales of Magic - Magic Object 560 - 571      857   Louse-Skin     621
#
#                         AT_label   Motif_code  \
# 0                                      D812.3
# 1                                     D1413.8
# 2                    Magic Knife         D838
# 3                    Magic Knife        D1083
# 4                    Magic Knife  D1400.1.4.3
# ..                           ...          ...
# 80  The Louse-Skin (now ATU 857)       B873.1
# 81  The Louse-Skin (now ATU 857)       F983.2
# 82  The Louse-Skin (now ATU 857)         H551
# 83  The Louse-Skin (now ATU 857)       H522.1
# 84  The Louse-Skin (now ATU 857)       H573.3
#
#                                           Motif_label
# 0          †D812.3. Magic object received from devil.
# 1          †D1413.8. Chamber-pot to which one sticks.
# 2            †D838. Magic object acquired by stealing
# 3                                †D1083. Magic knife.
# 4           †D1400.1.4.3. Magic knife conquers enemy.
# ..                                                ...
# 80                              †B873.1. Giant louse.
# 81                           †F983.2. Louse fattened.
# 82  †H551. Princess offered to man who can out-rid...
# 83    †H522.1. Test: guessing origin of certain skin.
# 84  †H573.3. Riddle solved by listening to propoun...
#
# [85 rows x 10 columns]

# %% [markdown]
# We can add those codes to a simple database. Let's create the database first:

# %%
from sqlite_utils import Database

db_name = "tale_types_demo.db"

# While developing the script, recreate database each time...
db = Database(db_name, recreate=True)

# %%
db["tale_types"].delete_where()

table_df.to_sql("tale_types", index=False, con=db.conn)
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %% [markdown]
# Try a test query:

# %%
from pandas import read_sql

q = "SELECT * FROM tale_types LIMIT 3"

read_sql(q, db.conn)
# Out:
#   ATU Classification Type AT Classification Type  \
# 0
# 1
# 2     ATU 576 Magic Knife     AT 576 Magic Knife
#
#                                       Thompson Motif  \
# 0  D812.3. †D812.3. Magic object received from de...
# 1  D1413.8. †D1413.8. Chamber-pot to which one st...
# 2     D838. †D838. Magic object acquired by stealing
#
#                                   category ATU_code    ATU_label AT_code  \
# 0  Tales of Magic - Magic Object 560 - 571
# 1  Tales of Magic - Magic Object 560 - 571
# 2  Tales of Magic - Magic Object 560 - 571      576  Magic Knife     576
#
#       AT_label Motif_code                                 Motif_label
# 0                  D812.3  †D812.3. Magic object received from devil.
# 1                 D1413.8  †D1413.8. Chamber-pot to which one sticks.
# 2  Magic Knife       D838    †D838. Magic object acquired by stealing

# %% [markdown]
# We can create a simple function to scrape all the tables on the page, process them and add them to the database.
#
# We can also add the page title as a column entry.

# %%
def process_dataframe1(table_df, category):
    """Process the """
    #Explicitly set column names
    table_df.columns = ["ATU Classification Type", "AT Classification Type", "Thompson Motif"]

    # Remove column names if they were in the table
    table_df = table_df[table_df["ATU Classification Type"]!="ATU Classification Type"].reset_index(drop=True)

    table_df['category'] = category
   
    return table_df

def patch_motif_label(cell):
    """Fix borked motif label."""
    if cell and cell.startswith("†"):
        parts = cell.split()
        return  pd.Series({"Motif_label": " ".join(parts[1:])})
    return pd.Series({"Motif_label":''})
    
def process_dataframe2(table_df):
    """Process the """   
    # Fill down on blanks
    table_df = table_df.replace("", None).fillna(method="ffill")
    table_df[["ATU_code","ATU_label"]]= table_df["ATU Classification Type"].apply(ATU_splitter)
    table_df[["AT_code","AT_label"]]= table_df["AT Classification Type"].apply(AT_splitter)
    table_df[["Motif_code","Motif_label"]]= table_df["Thompson Motif"].apply(Thompson_Motif_splitter)
    
    # There may be some cruft in Motif_label
    table_df[["Motif_label"]]= table_df["Motif_label"].apply(patch_motif_label)

    return table_df

    
def scrape_page_tables(url):
    """Scrape all the tables on the page."""
    response = session.get(url)

    # dot notation: . is class, # is id
    #s-lib-box s-lib-box-std
    boxes = response.html.find('.s-lib-box')
    
    tables = []
    
    for i, box in enumerate(boxes):
        category = box.find('h2')[0].text
        
        # Some pages have cruft boxes with no tables
        _tables = box.find('table')
        if not _tables:
            continue
        table = _tables[0]
    
        if i==0:
            # There may be cruft empty tables at the top of the page
            try:
                table_df = pd.read_html(table.html, skiprows=3)[0]
                table_df = table_df.dropna(axis=0, how='all').reset_index(drop=True).fillna('')
            except:
                continue
        else:
            table_df = pd.read_html(table.html)[0]
            table_df = table_df.dropna(axis=0, how='all').reset_index(drop=True).fillna('')

        table_df = process_dataframe1(table_df, category)

        # Some dataframes are actually multiple dataframes
        split_indexes = table_df[table_df["ATU Classification Type"].str.startswith("__")].index.to_list()
        if split_indexes:
            split_dfs = []
            prev_ix = 0
            for ix in split_indexes:
                tmp_df = table_df.iloc[prev_ix:ix, :].reset_index(drop=True)
                split_dfs.append(tmp_df)
                prev_ix = ix

            # Remaining part:
            tmp_df = table_df.iloc[prev_ix:, :].reset_index(drop=True)
            split_dfs.append(tmp_df)

            for split_df in split_dfs[1:]:
                partial_category = split_df.iloc[0, 2]
                split_df["category"] = partial_category
                split_df = split_df.drop(0).reset_index(drop=True)
                split_df = process_dataframe2(split_df)
                tables.append(split_df)
                
        else:
            table_df = process_dataframe2(table_df)
            tables.append(table_df)
    return tables

# %%
index_links[5]
# Out:
# 'https://libraryguides.missouri.edu/c.php?g=1039894&p=7624305'

# %% [markdown]
# Let's try it out:

# %%
scrape_page_tables(index_links[5])[0]
# Out:
#                ATU Classification Type  \
# 0           ATU 1030 The Crop Division
# 1       ATU 1036 Hogs with Curly Tails
# 2   ATU 1045 Pulling the Lake Together
# 3               ATU 1049 The heavy axe
# 4               ATU 1049 The heavy axe
# 5               ATU 1050 Felling trees
# 6               ATU 1050 Felling trees
# 7               ATU 1050 Felling trees
# 8              ATU 1051 Bending a Tree
# 9             ATU 1052 Carrying a Tree
# 10        ATU 1053 Shooting Wild Boars
#
#                          AT Classification Type  \
# 0        AT 1030 Man and Ogre Share the Harvest
# 1                 AT 1036 Hogs with Curly Tails
# 2   AT 1045 Pulling Down the Forest with a Rope
# 3     AT 1049 The heavy Axe or the Giant Bucket
# 4     AT 1049 The heavy Axe or the Giant Bucket
# 5              AT 1050 Contest in Felling Trees
# 6              AT 1050 Contest in Felling Trees
# 7              AT 1050 Contest in Felling Trees
# 8            AT 1051 Springing with a Bent Tree
# 9          AT 1052 A Contest in Carrying a Tree
# 10                  AT 1053 Shooting Wild Boars
#
#                                        Thompson Motif  \
# 0   K171.1. Deceptive crop division: above the gro...
# 1   K171.4. Deceptive division of pigs: curly and ...
# 2   K1744. Hero threatens to pull the lake togethe...
# 3                  K1741.1. Felling the whole forest.
# 4                   K1741.3. Bringing the whole well.
# 5                 K44. Deceptive contest in chopping.
# 6          K178. Deceptive bargain: felling the tree.
# 7                   K1421. Clearing land: axe broken.
# 8                            K1112. Bending the tree.
# 9   K71. Deceptive contest in carrying a tree: rid...
# 10                   K1741.2. A thousand at one shot.
#
#                                         category ATU_code  \
# 0   Partnership between Man and Ogre 1030 - 1059     1030
# 1   Partnership between Man and Ogre 1030 - 1059     1036
# 2   Partnership between Man and Ogre 1030 - 1059     1045
# 3   Partnership between Man and Ogre 1030 - 1059     1049
# 4   Partnership between Man and Ogre 1030 - 1059     1049
# 5   Partnership between Man and Ogre 1030 - 1059     1050
# 6   Partnership between Man and Ogre 1030 - 1059     1050
# 7   Partnership between Man and Ogre 1030 - 1059     1050
# 8   Partnership between Man and Ogre 1030 - 1059     1051
# 9   Partnership between Man and Ogre 1030 - 1059     1052
# 10  Partnership between Man and Ogre 1030 - 1059     1053
#
#                     ATU_label AT_code                             AT_label  \
# 0           The Crop Division    1030       Man and Ogre Share the Harvest
# 1       Hogs with Curly Tails    1036                Hogs with Curly Tails
# 2   Pulling the Lake Together    1045  Pulling Down the Forest with a Rope
# 3               The heavy axe    1049    The heavy Axe or the Giant Bucket
# 4               The heavy axe    1049    The heavy Axe or the Giant Bucket
# 5               Felling trees    1050             Contest in Felling Trees
# 6               Felling trees    1050             Contest in Felling Trees
# 7               Felling trees    1050             Contest in Felling Trees
# 8              Bending a Tree    1051           Springing with a Bent Tree
# 9             Carrying a Tree    1052         A Contest in Carrying a Tree
# 10        Shooting Wild Boars    1053                  Shooting Wild Boars
#
#    Motif_code Motif_label
# 0      K171.1
# 1      K171.4
# 2       K1744
# 3     K1741.1
# 4     K1741.3
# 5         K44
# 6        K178
# 7       K1421
# 8       K1112
# 9         K71
# 10    K1741.2

# %% [markdown]
# We can now scrape the whole collection:

# %%
from tqdm.notebook import tqdm


# Note that this assumes a globally defined requests session and database
def scrape_pages(url="https://libraryguides.missouri.edu/c.php?g=1039894&p=7609090",
                 db_table="tale_types"):
    """Scrape all tale type lookup pages."""
    index_response = session.get(url)
    
    # Get links for lookup pages
    link_elements = response.html.find('.nav-tabs')[0].find("li")[1:-1]
    index_links = [el.xpath("//a/@href")[0] for el in link_elements]
    
    # Parse each page
    for index_link in tqdm(index_links):
        tables = scrape_page_tables(index_link)
        
        # Add to database
        # Note that we need to ensure we append the data to an existing table
        for table in tables:
            table.to_sql(db_table, index=False, if_exists="append", con=db.conn)

# %%
# Clear out the table
#db["tale_types"].drop()
db["tale_links"].delete_where()

# And scrape everything
scrape_pages()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
q = "SELECT * FROM tale_types LIMIT 3"

read_sql(q, db.conn)
# Out:
#   ATU Classification Type AT Classification Type  \
# 0
# 1
# 2     ATU 576 Magic Knife     AT 576 Magic Knife
#
#                                       Thompson Motif  \
# 0  D812.3. †D812.3. Magic object received from de...
# 1  D1413.8. †D1413.8. Chamber-pot to which one st...
# 2     D838. †D838. Magic object acquired by stealing
#
#                                   category ATU_code    ATU_label AT_code  \
# 0  Tales of Magic - Magic Object 560 - 571
# 1  Tales of Magic - Magic Object 560 - 571
# 2  Tales of Magic - Magic Object 560 - 571      576  Magic Knife     576
#
#       AT_label Motif_code                                 Motif_label
# 0                  D812.3  †D812.3. Magic object received from devil.
# 1                 D1413.8  †D1413.8. Chamber-pot to which one sticks.
# 2  Magic Knife       D838    †D838. Magic object acquired by stealing

# %%
q = "SELECT COUNT(*) AS numrows FROM tale_types"

read_sql(q, db.conn)
# Out:
#    numrows
# 0     2311

# %%
q = "SELECT * FROM tale_types WHERE ATU_code=610"

read_sql(q, db.conn)
# Out:
#       ATU Classification Type             AT Classification Type  \
# 0   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 1   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 2   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 3   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 4   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 5   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 6   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 7   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 8   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 9   ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 10  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 11  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 12  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 13  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 14  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 15  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 16  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 17  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 18  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 19  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 20  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 21  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 22  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
# 23  ATU 610 The Healing Fruit  AT 610 Fruit to Cure the Princess
#
#                                        Thompson Motif  \
# 0   T68.1. †T68.1. Princess offered as prize to re...
# 1   H346. †H346. Princess given to man who can hea...
# 2                           Q2. †Q2. Kind and unkind.
# 3              L13. †L13. Compassionate youngest son.
# 4                 L10. †L10. Victorious youngest son.
# 5                  N825.3. †N825.3. Old woman helper.
# 6         D1500.1.5. †D1500.1.5. Magic healing fruit.
# 7                     H1010. †H1010. Impossible tasks
# 8   D1533.1.1. †D1533.1.1. Magic land and water ship.
# 9               H1112. †H1112. Task: herding rabbits.
# 10  H1331.1.2.1. †H1331.1.2.1. Quest for remarkabl...
# 11           L161. †L161. Lowly hero marries princess
# 12  T68.1. †T68.1. Princess offered as prize to re...
# 13  H346. †H346. Princess given to man who can hea...
# 14                          Q2. †Q2. Kind and unkind.
# 15             L13. †L13. Compassionate youngest son.
# 16                L10. †L10. Victorious youngest son.
# 17                 N825.3. †N825.3. Old woman helper.
# 18        D1500.1.5. †D1500.1.5. Magic healing fruit.
# 19                    H1010. †H1010. Impossible tasks
# 20  D1533.1.1. †D1533.1.1. Magic land and water ship.
# 21              H1112. †H1112. Task: herding rabbits.
# 22  H1331.1.2.1. †H1331.1.2.1. Quest for remarkabl...
# 23           L161. †L161. Lowly hero marries princess
#
#                                     category ATU_code          ATU_label  \
# 0    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 1    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 2    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 3    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 4    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 5    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 6    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 7    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 8    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 9    Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 10   Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 11   Tales of Magic - Magic Object 560 - 571      610  The Healing Fruit
# 12  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 13  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 14  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 15  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 16  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 17  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 18  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 19  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 20  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 21  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 22  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
# 23  Tales of Magic - Magic Object 571B - 649      610  The Healing Fruit
#
#    AT_code                    AT_label   Motif_code  \
# 0      610  Fruit to Cure the Princess        T68.1
# 1      610  Fruit to Cure the Princess         H346
# 2      610  Fruit to Cure the Princess           Q2
# 3      610  Fruit to Cure the Princess          L13
# 4      610  Fruit to Cure the Princess          L10
# 5      610  Fruit to Cure the Princess       N825.3
# 6      610  Fruit to Cure the Princess    D1500.1.5
# 7      610  Fruit to Cure the Princess        H1010
# 8      610  Fruit to Cure the Princess    D1533.1.1
# 9      610  Fruit to Cure the Princess        H1112
# 10     610  Fruit to Cure the Princess  H1331.1.2.1
# 11     610  Fruit to Cure the Princess         L161
# 12     610  Fruit to Cure the Princess        T68.1
# 13     610  Fruit to Cure the Princess         H346
# 14     610  Fruit to Cure the Princess           Q2
# 15     610  Fruit to Cure the Princess          L13
# 16     610  Fruit to Cure the Princess          L10
# 17     610  Fruit to Cure the Princess       N825.3
# 18     610  Fruit to Cure the Princess    D1500.1.5
# 19     610  Fruit to Cure the Princess        H1010
# 20     610  Fruit to Cure the Princess    D1533.1.1
# 21     610  Fruit to Cure the Princess        H1112
# 22     610  Fruit to Cure the Princess  H1331.1.2.1
# 23     610  Fruit to Cure the Princess         L161
#
#                                           Motif_label
# 0       †T68.1. Princess offered as prize to rescuer.
# 1      †H346. Princess given to man who can heal her.
# 2                               †Q2. Kind and unkind.
# 3                   †L13. Compassionate youngest son.
# 4                      †L10. Victorious youngest son.
# 5                          †N825.3. Old woman helper.
# 6                    †D1500.1.5. Magic healing fruit.
# 7                            †H1010. Impossible tasks
# 8              †D1533.1.1. Magic land and water ship.
# 9                      †H1112. Task: herding rabbits.
# 10  †H1331.1.2.1. Quest for remarkable bird feathers.
# 11                 †L161. Lowly hero marries princess
# 12              Princess offered as prize to rescuer.
# 13            Princess given to man who can heal her.
# 14                                   Kind and unkind.
# 15                        Compassionate youngest son.
# 16                           Victorious youngest son.
# 17                                  Old woman helper.
# 18                               Magic healing fruit.
# 19                                   Impossible tasks
# 20                         Magic land and water ship.
# 21                             Task: herding rabbits.
# 22                Quest for remarkable bird feathers.
# 23                        Lowly hero marries princess

# %% [markdown]
# # Story Scraper
#
# The Missouri Libraries website also maintain a collection of stories referenced by AT and ATU categorised tale types: https://libraryguides.missouri.edu/c.php?g=1083510

# %%
tales_index_url = "https://libraryguides.missouri.edu/c.php?g=1083510"

# %%
session = HTMLSession()
tales_index_response = session.get(tales_index_url)

# %% [markdown]
# We can get links for the separate index pages as we did before:

# %%
tales_link_elements = tales_index_response.html.find('.nav-tabs')[0].find("li")[:-2]
tales_index_links = [el.xpath("//a/@href")[0] for el in tales_link_elements]
tales_index_links
# Out:
# ['https://libraryguides.missouri.edu/c.php?g=1083510&p=7898512',
#  'https://libraryguides.missouri.edu/c.php?g=1083510&p=7901911',
#  'https://libraryguides.missouri.edu/c.php?g=1083510&p=7913834',
#  'https://libraryguides.missouri.edu/c.php?g=1083510&p=7916779',
#  'https://libraryguides.missouri.edu/c.php?g=1083510&p=7916818',
#  'https://libraryguides.missouri.edu/c.php?g=1083510&p=7916872',
#  'https://libraryguides.missouri.edu/c.php?g=1083510&p=7917477']

# %% [markdown]
# There is just a single box per page although it may contain several tables:

# %%
tales_response = session.get(tales_index_links[1])

# dot notation: . is class, # is id
#s-lib-box s-lib-box-std
boxes = tales_response.html.find('.s-lib-box')
boxes
# Out:
# [<Element 'div' id='s-lg-box-25061504' class=('s-lib-box', 's-lib-box-std')>]

# %% [markdown]
# As before, we can extract the box title as a category heading:

# %%
category = boxes[0].find('h2')[0].text
category
# Out:
# 'ATU 300 - 559 Tales of Magic'

# %%
example_tales_tables = boxes[0].find('table')
example_tales_tables[:3]
# Out:
# [<Element 'table' border='1' cellpadding='0' cellspacing='0' dir='ltr' style='table-layout:fixed;font-size:10pt;font-family:Arial;width:0px;border-collapse:collapse;border:none' xmlns='http://www.w3.org/1999/xhtml'>,
#  <Element 'table' border='1' cellpadding='0' cellspacing='0' dir='ltr' style='table-layout:fixed;font-size:10pt;font-family:Arial;width:0px;border-collapse:collapse;border:none' xmlns='http://www.w3.org/1999/xhtml'>,
#  <Element 'table' border='1' cellpadding='0' cellspacing='0' dir='ltr' style='table-layout:fixed;font-size:10pt;font-family:Arial;width:0px;border-collapse:collapse;border:none' xmlns='http://www.w3.org/1999/xhtml'>]

# %% [markdown]
# Each table can be mapped to a dataframe, removing empty rows and filling down on the blanks.
#
# The columns could be detected, but they are consistent and will need rolling over for multiple tables in a box, so we might as well set them explicitly and then tidy up.

# %%
example_df = pd.read_html(example_tales_tables[0].html)[0]
example_df = example_df.dropna(how='all').fillna(method='ffill')
example_df.columns = ["ATU Title", "AT", "Title", "Origin"]

# Remove column names if they were in the table and reset index
example_df = example_df[example_df["ATU Title"]!="ATU Title"].reset_index(drop=True)

# Tidy AT
example_df["AT"] = example_df["AT"].str.replace("*", "", regex=False)
# Tidy ATU Title
example_df["ATU Name"] = example_df["ATU Title"].apply(lambda x: " ".join(x.split()[2:]))
example_df.head()
# Out:
#                    ATU Title   AT                               Title  \
# 0  ATU 300 The Dragon-Slayer  300  Three Brothers and the three Tasks
# 1  ATU 300 The Dragon-Slayer  300                          Three Dogs
# 2  ATU 300 The Dragon-Slayer  300     Black Crow and the White Cheese
# 3  ATU 300 The Dragon-Slayer  300                       Five Counsels
# 4  ATU 300 The Dragon-Slayer  300                     Monster's Hairs
#
#      Origin           ATU Name
# 0   British  The Dragon-Slayer
# 1    German  The Dragon-Slayer
# 2  Egyptian  The Dragon-Slayer
# 3   Mexican  The Dragon-Slayer
# 4  Armenian  The Dragon-Slayer

# %% [markdown]
# Also note that we need to parse out the link for the tale in the HTML table. The *pandas* `.read_html()` function does not do this out of the can, although we can patch *pandas* to support it. Alternatively, we can grab the links from the table.

# %%
from bs4 import BeautifulSoup

def get_table_links(html):
    """Parse an HMTL table and extract links from it."""
    table_soup = BeautifulSoup(html, 'lxml')

    links = []
    for row in table_soup.find_all('tr'):
        for td in row.find_all('td'):
            if td.find('a'):
                links.append((td.a['href'], td.text))

    link_df = pd.DataFrame(links, columns=["link", "Title"])
    
    return link_df

link_df = get_table_links(example_tales_tables[0].html)
link_df.head()
# Out:
#                                                 link  \
# 0  https://archive.org/details/dictionaryofbrit01...
# 1  https://archive.org/details/greenfairybook00la...
# 2  https://archive.org/details/folktalesofegypt00...
# 3  https://archive.org/details/folktalesofmexic00...
# 4  https://archive.org/details/100armeniantales00...
#
#                                 Title
# 0  Three Brothers and the three Tasks
# 1                          Three Dogs
# 2     Black Crow and the White Cheese
# 3                       Five Counsels
# 4                     Monster's Hairs

# %% [markdown]
# Note that there may be duplicate story names within a table, so we will join by the index value.

# %%
example_df = example_df.join(link_df["link"])
example_df.head()
# Out:
#                    ATU Title   AT                               Title  \
# 0  ATU 300 The Dragon-Slayer  300  Three Brothers and the three Tasks
# 1  ATU 300 The Dragon-Slayer  300                          Three Dogs
# 2  ATU 300 The Dragon-Slayer  300     Black Crow and the White Cheese
# 3  ATU 300 The Dragon-Slayer  300                       Five Counsels
# 4  ATU 300 The Dragon-Slayer  300                     Monster's Hairs
#
#      Origin           ATU Name  \
# 0   British  The Dragon-Slayer
# 1    German  The Dragon-Slayer
# 2  Egyptian  The Dragon-Slayer
# 3   Mexican  The Dragon-Slayer
# 4  Armenian  The Dragon-Slayer
#
#                                                 link
# 0  https://archive.org/details/dictionaryofbrit01...
# 1  https://archive.org/details/greenfairybook00la...
# 2  https://archive.org/details/folktalesofegypt00...
# 3  https://archive.org/details/folktalesofmexic00...
# 4  https://archive.org/details/100armeniantales00...

# %% [markdown]
# To parse the page completely, we'd need to iterate over all the tables.
#
# Let's build a scraper for all the pages and all the tables in a page:

# %%
def scrape_tale_links(url="https://libraryguides.missouri.edu/c.php?g=1083510",
                      db_table="tale_links"):
    """Scrape all tale links."""
    
    tales_index_response = session.get(url)
    
    tales_link_elements = tales_index_response.html.find('.nav-tabs')[0].find("li")[:-2]
    tales_index_links = [el.xpath("//a/@href")[0] for el in tales_link_elements]

    for tales_page_link in tqdm(tales_index_links):
        tales_response = session.get(tales_page_link)
        # dot notation: . is class, # is id
        #s-lib-box s-lib-box-std
        boxes = tales_response.html.find('.s-lib-box')

        category = boxes[0].find('h2')[0].text

        tables =  boxes[0].find('table')

        for table in tables:
            table_df = pd.read_html(table.html)[0]
            table_df = table_df.dropna(how='all').reset_index(drop=True).fillna(method='ffill')
            table_df.columns = ["ATU Title", "AT", "Title", "Origin"]
            table_df["AT"] = table_df["AT"].astype(str)
            table_df["ATU Title"] = table_df["AT"].astype(str)

            table_df["category"] = category

            # Remove column names if they were in the table
            table_df = table_df[table_df["ATU Title"]!="ATU Title"]

            # Tidy AT
            table_df["AT"] = table_df["AT"].str.replace("*", "", regex=False)
            # Tidy ATU Title
            table_df["ATU Name"] = table_df["ATU Title"].apply(lambda x: " ".join(x.split()[2:]))
            
            # Add links
            link_df = get_table_links(example_tales_tables[0].html)
            table_df = table_df.join(link_df["link"])
            
            table_df.to_sql(db_table, if_exists="append", index=False, con=db.conn)

# %%
# Clear the db table (if it exists)
#db["tale_links"].drop()
db["tale_links"].delete_where()

scrape_tale_links()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
q = "SELECT * FROM tale_links LIMIT 10"

read_sql(q, db.conn)
# Out:
#   ATU Title  AT                            Title     Origin  \
# 0        AT  AT                            Title     Origin
# 1         1   1             The Wolf and the Fox     French
# 2         1   1                  Fox in Inishkea      Irish
# 3         1   1                       Fish Thief  Japanesse
# 4         1   1                    Tub of Butter   Canadian
# 5         1   1                     Fox and Lapp       Lapp
# 6         1   1                Reynard and Bruin   European
# 7        1*   1       Fox and the Hare in Winter     German
# 8        1*   1               Fox and the Magpie    British
# 9        1*   1  Hare, Badger, Monkey, and Otter  Japanesse
#
#                  category ATU Name  \
# 0  ATU 1-299 Animal Tales
# 1  ATU 1-299 Animal Tales
# 2  ATU 1-299 Animal Tales
# 3  ATU 1-299 Animal Tales
# 4  ATU 1-299 Animal Tales
# 5  ATU 1-299 Animal Tales
# 6  ATU 1-299 Animal Tales
# 7  ATU 1-299 Animal Tales
# 8  ATU 1-299 Animal Tales
# 9  ATU 1-299 Animal Tales
#
#                                                 link
# 0  https://archive.org/details/dictionaryofbrit01...
# 1  https://archive.org/details/greenfairybook00la...
# 2  https://archive.org/details/folktalesofegypt00...
# 3  https://archive.org/details/folktalesofmexic00...
# 4  https://archive.org/details/100armeniantales00...
# 5  https://archive.org/details/irishfolktales00gl...
# 6  https://archive.org/details/greenhillsofmagi00...
# 7  https://archive.org/details/irishfolktales00gl...
# 8  https://archive.org/details/moreenglishfairy00...
# 9  https://archive.org/details/greyfairybook00lan...

# %% [markdown]
# Lots of the links are to resources held by `archive.org`,  although many of them are limited preview books.
#
# It might be interesting trying to build something to check whether a resource is openly available there, or limited access, and if it is openly available, perhaps attempt to scrape the story text from the Internet Archive.

# %% [markdown]
# ## Identifying Openly Available `archive.org` Resources
#
# Let's start by just grabbing a list of unique resources on `archive.org`:

# %%
q = 'SELECT * FROM tale_links WHERE link LIKE "https://archive.org/details/%";'

xx = read_sql(q, db.conn)
xx['resource'] = xx['link'].str.replace("https://archive.org/details/", "", regex=False)
xx['resource'] = xx['resource'].apply(lambda x: x.split("/")[0])
xx['resource'].unique()
# Out:
# array(['dictionaryofbrit01brig', 'greenfairybook00lang_0',
#        'folktalesofegypt00elsh', 'folktalesofmexic0000pare',
#        '100armeniantales0000unse', 'irishfolktales00glas',
#        'greenhillsofmagi0000musi', 'moreenglishfairy00jaco',
#        'greyfairybook00lang', 'russianfairytale00afan',
#        'folktalesofgreec0000mega', 'englishfairytale1902jaco',
#        'italianfolktales00calv', 'populartalesfrom00daseiala',
#        'yellowfairybook00lang02', 'folktalesofgerma00kurt',
#        'bluefairybook00langiala', 'brownfairybook00langrich',
#        'folktalesoffranc00mass', 'folktalesofjapan00seki',
#        'moregreekfolktal0000dawk', 'violetfairybook00lang'], dtype=object)

# %% [markdown]
# I've already got a database of the Lang coloured Fairy Books, so it should be possible to join in to that.
